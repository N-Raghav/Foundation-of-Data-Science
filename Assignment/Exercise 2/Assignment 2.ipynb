# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)        NaN
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11503 non-null  float64
#  5   Engine Cylinders   11411 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11503.000000      11411.000000     11908.000000
# mean    2010.384338    249.304355          5.631321         3.436093
# std        7.579740    109.176671          1.780997         0.881315
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    170.000000          4.000000         2.000000
# 50%     2015.000000    227.000000          6.000000         4.000000
# 75%     2016.000000    300.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)        NaN
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
sns.boxplot(data=df['Year'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df['Engine HP'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df['Engine Cylinders'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df['highway MPG'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df['city mpg'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df['Popularity'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df['MSRP'])
# Out:
# <AxesSubplot:>

# %%
df.isnull()
# Out:
#         Make  Model   Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0      False  False  False             False      False             False
# 1      False  False  False             False      False             False
# 2      False  False  False             False      False             False
# 3      False  False  False             False      False             False
# 4      False  False  False             False      False             False
# ...      ...    ...    ...               ...        ...               ...
# 11909  False  False  False             False      False             False
# 11910  False  False  False             False      False             False
# 11911  False  False  False             False       True             False
# 11912  False  False  False             False      False             False
# 11913  False  False  False             False      False             False
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# ...

# %%
df['Make'].unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %%
#using ffill method to fill the NaN values in the Market Category column
df['Market Category'].fillna(method='ffill',inplace=True)

# %%
df.info() #to check if the column has been updated
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11503 non-null  float64
#  5   Engine Cylinders   11411 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    11914 non-null  object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df['Number of Doors'].dropna(inplace=True)

# %%
df['Engine Fuel Type'].dropna(inplace=True)

# %%
df['Engine HP'].fillna(value=df['Engine HP'].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11914 non-null  float64
#  5   Engine Cylinders   11411 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    11914 non-null  object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df['Engine Cylinders'].fillna(value=df['Engine Cylinders'].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11914 non-null  float64
#  5   Engine Cylinders   11914 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    11914 non-null  object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
grp=df.groupby(['Engine Fuel Type'])

# %%
def IQR(data,column):
    q1=data[column].quantile(0.25)
    q3=data[column].quantile(0.75)
    iqr=q3-q1
    upper=q3+1.5*iqr
    lower=q1-1.5*iqr
    return iqr,q1,q3,upper,lower

# %%
iqr,q1,q3,upper,lower=IQR(df,"Engine HP")
df=df[(df['Engine HP']>lower) & (df['Engine HP']<=upper)]

# %%
iqr,q1,q3,upper,lower=IQR(df,"Engine Cylinders")
df=df[(df['Engine Cylinders']>lower) & (df['Engine Cylinders']<=upper)]

# %%
iqr,q1,q3,upper,lower=IQR(df,"Number of Doors")
df=df[(df['Number of Doors']>lower) & (df['Number of Doors']<=upper)]

# %%
iqr,q1,q3,upper,lower=IQR(df,"Number of Doors")
df=df[(df['Number of Doors']>lower) & (df['Number of Doors']<=upper)]

# %%
iqr,q1,q3,upper,lower=IQR(df,"highway MPG")
df=df[(df['highway MPG']>lower) & (df['highway MPG']<=upper)]

# %%
iqr,q1,q3,upper,lower=IQR(df,"city mpg")
df=df[(df['city mpg']>lower) & (df['city mpg']<=upper)]

# %%
iqr,q1,q3,upper,lower=IQR(df,"Popularity")
df=df[(df['Popularity']>lower) & (df['Popularity']<=upper)]

# %%
iqr,q1,q3,upper,lower=IQR(df,"MSRP")
df=df[(df['MSRP']>lower) & (df['MSRP']<=upper)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9685 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               9685 non-null   object
#  1   Model              9685 non-null   object
#  2   Year               9685 non-null   int64
#  3   Engine Fuel Type   9682 non-null   object
#  4   Engine HP          9685 non-null   float64
#  5   Engine Cylinders   9685 non-null   float64
#  6   Transmission Type  9685 non-null   object
#  7   Driven_Wheels      9685 non-null   object
#  8   Number of Doors    9685 non-null   float64
#  9   Market Category    9685 non-null   object
#  10  Vehicle Size       9685 non-null   object
#  11  Vehicle Style      9685 non-null   object
#  12  highway MPG        9685 non-null   int64
#  13  city mpg           9685 non-null   int64
#  14  Popularity         9685 non-null   int64
#  15  MSRP               9685 non-null   int64
# ...

# %%
for i in df.select_dtypes(include='object'):
    print(df[i].value_counts())
# Out:
# Chevrolet        1079
# Volkswagen        777
# Toyota            670
# Dodge             602
# Nissan            537
# GMC               514
# Mazda             419
# Honda             384
# Suzuki            350
# Infiniti          329
# Cadillac          296
# Hyundai           294
# Volvo             281
# Audi              274
# Subaru            256
# Acura             245
# Mercedes-Benz     237
# BMW               220
# Kia               218
# Buick             196
# Mitsubishi        193
# Chrysler          187
# Pontiac           186
# Lexus             162
# Oldsmobile        150
# Lincoln           147
# Saab              111
# Land Rover         93
# Plymouth           82
# FIAT               59
# Scion              55
# Porsche            37
# Lotus              18
# HUMMER             17
# Alfa Romeo          5
# Genesis             3
# Maserati            2
# Name: Make, dtype: int64
# Silverado 1500        156
# Tundra                140
# Sierra 1500            90
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9685 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               9685 non-null   object
#  1   Model              9685 non-null   object
#  2   Year               9685 non-null   int64
#  3   Engine Fuel Type   9682 non-null   object
#  4   Engine HP          9685 non-null   float64
#  5   Engine Cylinders   9685 non-null   float64
#  6   Transmission Type  9685 non-null   object
#  7   Driven_Wheels      9685 non-null   object
#  8   Number of Doors    9685 non-null   float64
#  9   Market Category    9685 non-null   object
#  10  Vehicle Size       9685 non-null   object
#  11  Vehicle Style      9685 non-null   object
#  12  highway MPG        9685 non-null   int64
#  13  city mpg           9685 non-null   int64
#  14  Popularity         9685 non-null   int64
#  15  MSRP               9685 non-null   int64
# ...

# %%
df[(df['Transmission Type']=='MANUAL')& (df['Driven_Wheels']=='rear wheel drive')].mean()['Engine HP']
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_127656\1337821305.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df['Transmission Type']=='MANUAL')& (df['Driven_Wheels']=='rear wheel drive')].mean()['Engine HP']
# 235.5916594369642

# %%
grp=df.groupby(['Make','Vehicle Style'])

# %%
grp['Make'].min()
# Out:
# Make   Vehicle Style
# Acura  2dr Hatchback    Acura
#        4dr Hatchback    Acura
#        4dr SUV          Acura
#        Coupe            Acura
#        Sedan            Acura
#                         ...
# Volvo  4dr SUV          Volvo
#        Convertible      Volvo
#        Coupe            Volvo
#        Sedan            Volvo
#        Wagon            Volvo
# Name: Make, Length: 245, dtype: object

# %%
grp['Vehicle Style'].describe(include=['object']).T
# Out:
# Make                   Acura                                               \
# Vehicle Style  2dr Hatchback  4dr Hatchback  4dr SUV  Coupe  Sedan  Wagon
# count                     28              7       62     15    127      6
# unique                     1              1        1      1      1      1
# top            2dr Hatchback  4dr Hatchback  4dr SUV  Coupe  Sedan  Wagon
# freq                      28              7       62     15    127      6
#
# Make            Alfa Romeo                  Audi           ... Volkswagen  \
# Vehicle Style  Convertible  Coupe  2dr Hatchback  4dr SUV  ...      Coupe
# count                    2      3              2       55  ...          4
# unique                   1      1              1        1  ...          1
# top            Convertible  Coupe  2dr Hatchback  4dr SUV  ...      Coupe
# freq                     2      3              2       55  ...          4
#
# Make                                                    Volvo           \
# ...

# %%
grp['city mpg'].min()
# Out:
# Make   Vehicle Style
# Acura  2dr Hatchback    20
#        4dr Hatchback    16
#        4dr SUV          13
#        Coupe            15
#        Sedan            15
#                         ..
# Volvo  4dr SUV          16
#        Convertible      18
#        Coupe            15
#        Sedan            15
#        Wagon            15
# Name: city mpg, Length: 245, dtype: int64

# %%
grp['city mpg'].max()
# Out:
# Make   Vehicle Style
# Acura  2dr Hatchback    24
#        4dr Hatchback    16
#        4dr SUV          20
#        Coupe            17
#        Sedan            28
#                         ..
# Volvo  4dr SUV          24
#        Convertible      19
#        Coupe            17
#        Sedan            26
#        Wagon            25
# Name: city mpg, Length: 245, dtype: int64

# %%
grp['city mpg'].mean()
# Out:
# Make   Vehicle Style
# Acura  2dr Hatchback    22.178571
#        4dr Hatchback    16.000000
#        4dr SUV          18.725806
#        Coupe            16.466667
#        Sedan            20.385827
#                           ...
# Volvo  4dr SUV          20.056338
#        Convertible      18.666667
#        Coupe            16.000000
#        Sedan            19.590000
#        Wagon            19.285714
# Name: city mpg, Length: 245, dtype: float64

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df)

# %%
sns.jointplot(data=df,x='Engine HP',y='MSRP')

# %%
sns.lmplot(data=df,x='Engine HP',y='highway MPG',hue='Engine Cylinders')

# %%
plt.hist(df['MSRP'],bins=50)
plt.show()

# %%
plt.scatter(x=df['city mpg'],y=df['highway MPG'])
